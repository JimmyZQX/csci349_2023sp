# %% [markdown]
# # Lab 05 - Data Visualization I
#
# **DUE: Feb 6, 2023 (Monday)**
# Pair Programming: Optional
#
# Name: Jimmy Zhu
# Class: CSCI 349 - Intro to Data Mining
# Semester: Spring 2023
# Instructor: Brian King
#
# ## Objectives
# * The basics of `matplotlib` and `seaborn` for data visualizations in Python

# %% [markdown]
# ---
# ## A Reminder…
# This is a reminder of what you are in the midst of embarking on – a journey into the depths and complexity (and the sheer joy!) of data science, with a lot of emphasis on machine learning and data mining.  You are learning about one of the hottest, most sought after skillsets in industry today. It does not come easy, and the depth of knowledge required to become a solid, highly sought-after candidate is immense. The amount you are able to take away from this course will be entirely up to you. This is an active-learning, hands-on course, designed for you to learn through experience. Applying what you learn, rather than sitting and taking notes. And, the labs get progressively more complex. As an upper-level elective, you are expected to delve in deeply into this material, independently, and collaborations with a peer in a pair programming setting is welcome.

# %% [markdown]
# ---
# ## Introduction
# Matplotlib is the standard plotting library in Python. It has been around a very, very long time, and frankly, it shows.  It's tedious, overly complicated, challenging to learn, and the output always seems to look generic and outdated unless you're willing to take some time with its formatting API. With some effort, you can configure your plots to look great, but effort is the key word there! Thankfully, there are better interfaces out there. Yet, many higher level, more advanced plotting libraries are built on matplotlib. Thus, most experts agree that taking time to learn matplotlib is a really valuable skill, and makes learning the advanced interfaces easier. So, that is where we are going to start.
#
# We're going to introduce you to TWO data plotting and visualization frameworks in this lab:
# * [Matplotlib](https://matplotlib.org/stable/index.html) – the core, most essential framework for generating plots in Python
# * [Seaborn](https://seaborn.pydata.org/index.html) – built on top of Matplotlib, much easier and more intuitive, with better results most of the time
#
# Before you begin these exercises, if you are not familiar with matplotlib, I strongly recommend that you work through the short, concise, but highly effective [beginner's tutorial on the pyplot interface of matplotlib](https://matplotlib.org/stable/tutorials/introductory/pyplot.html) . It is completely worth your time if you know nothing about matplotlib.
#
# Then, take a moment to peruse through the other [tutorials on Matplotlib](https://matplotlib.org/stable/tutorials/index.html). Keep it in mind, and just page through some of these tutorials and example code. It has a wealth of example code you'll find useful for the rest of the semester.
#
# ---
# ## From Data to Visualizations
#
# Conveying information and knowledge about our data is an essential part of the data science pipeline. Whether you are in the early stages trying to understand the data you've been given, or you are at the end of your pipeline and generating plots conveying information about your models, you need to know how to generate good, meaningful plots.
#
# > An entire course could be taught about data visualization. Clearly, we don't have the time for that. This first lab will scrape the surface of what you can do with a good data visualization package. I strongly encourage you to take a bit of time and check out the variety of linkes and references included in the **References:** section below.
#
# There are a lot of ways we can visualize our data, but we must understand the type of our data first. (I cannot overstate the importance of understanding your data types as your first step. It is essential for every part of the data mining pipeline.) This lab is going to step you through a large number of exercises to help you understand the most common visualizations of your data, and for what type of data they are good for.
#
# I STRONGLY encourage you to explore the following web site:
#
# [From Data to Viz](https://www.data-to-viz.com/)
#
# This is one of my most favorite sites to help students make sense of all of the different visualizations out there. Take a moment to go through it, and bookmark it for reference. It will have answers to a lot of the questions you are going to be asked.

# %% [markdown]
# ---
# ## References
#
# The following are references I keep handy, as well as additional material I've worked through in the past to gain a good understanding of how these powerful data visualization APIs work:
#
# ### Tutorials and Essentials
#
# * [From Data to Viz](https://www.data-to-viz.com/)
# * [Pyplot](https://matplotlib.org/tutorials/introductory/pyplot.html) - Getting started
# * [Matplotlib Tutorials](https://matplotlib.org/tutorials/index.html) - (Of course, lots of sample exercises)
# * [Seaborn's Tutorial](https://seaborn.pydata.org/tutorial.html) - Good stuff, lot's of these exercises are based on this material.
# * [Pandas API to plotting](https://pandas.pydata.org/docs/user_guide/visualization.html) - Pandas has a very easy to use interface for generating a variety of quick plots. It uses matplotlib.
#
# ### APIs
# * [Matplotlib](https://matplotlib.org/stable/api/index.html)
# * [Seaborn](https://seaborn.pydata.org/api.html)
#
# ### Books and courses
#
# Some other useful references for the curious mind. Some of these are for a variety of courses available on [Datacamp](https://datacamp.com)
# * [Datacamp data viz w/ matplotlib](https://app.datacamp.com/learn/courses/introduction-to-data-visualization-with-matplotlib)
# * [Datacamp data viz w/ seaborn](https://app.datacamp.com/learn/courses/introduction-to-data-visualization-with-seaborn)
# * [Datacamp data vis w/ seaborn II](https://app.datacamp.com/learn/courses/intermediate-data-visualization-with-seaborn)
# * [McKinney's Python for Data Analysis, 3rd ed, ch09](https://learning.oreilly.com/library/view/python-for-data/9781098104023/ch09.html)
# * [VanderPlas's Python Data Science Handbook, 2nd ed, ch25-36](https://learning.oreilly.com/library/view/python-data-science/9781098121211/part04.html)
# * * [Scientific Visualization](https://github.com/rougier/scientific-visualization-book)
#
# ### Data
# * Seaborn datasets - https://github.com/mwaskom/seaborn-data
# * Common R datasets as CSV files - https://vincentarelbundock.github.io/Rdatasets/datasets.html
#
# ### Cheatsheets
#
# * [Matplotlib Cheatsheets](https://github.com/matplotlib/cheatsheets)

# %%
# This magic command just allows the autocomplete <TAB> 
# feature to work properly if using Jupyter
# %config Completer.use_jedi = False

# %% [markdown]
# ---
# ## DIRECTIONS
#
# **Answer each question below, paying close attention to the [P] to show your answer in Python, or [M] to show your answer in markdown, or both.** Remember, these notebook files will server as great references for your future. So, you are always welcome to include additional markdown for your own reference, as long as you answer the question.
#
# > This is the first lab where you are being provided with the skeleton .ipynb file. Each question is clearly marked, and most questions will have either a **code** or a **markdown** cell already provided with an `# ANSWER` or an **ANSWER:** header, repsectively. You are welcome to include additional cells as needed, particularly if you want to explain your answers or break up your code in a meaningful way. Sometimes I include all the cells you need, sometimes you may need more or less. Add whatever cells you need to best organize your code and generate a clean answer.

# %% [markdown]
# ---
# # Part I - matplotlib
# ---
# This diagram is your sanity as you begin to wrap your head around this visualization framework. The names that are used to label the important entities on the plot below match the names used in the API. Study it. It's in their main tutorial:
#
# <img alt="Img" height="700" src="https://matplotlib.org/stable/_images/anatomy.png" width="700"/>

# %%
# Our standard header to import our packages we'll be using. mpl, and sns are standard import aliases used by the Python community

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

print("np version:",np.__version__)
print("pd version:",pd.__version__)
print("mpl version:",mpl.__version__)
print("sns version:",sns.__version__)
# Out:
# np version: 1.23.5
# pd version: 1.5.2
# mpl version: 3.6.2
# sns version: 0.12.2

# %% [markdown]
# ---
# **1)**	[M] Read [matplotlib Quick Start Guide](https://matplotlib.org/tutorials/introductory/usage.html) first section on the **Parts of a Figure**. Then, summarize the following important parts of a plot:
#
# a.	Figure
# b.	Axes
# c.	Axis
# d.	Artist

# %% [markdown]
# **ANSWER:**
#
# From https://matplotlib.org/tutorials/introductory/usage.html
#
# a. Matplotlib plots the graph on a Figure, which contains one or more Axes, an area where points can be specified in terms of x-y coordinates. The Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc), and even nested subfigures.
#
# b. An Axes is an Artist attached to a Figure that contains a region for plotting data, and usually includes two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) that provide ticks and tick labels to provide scales for the data in the Axes. Each Axes also has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).
#
# c. These objects set the scale and limits and generate ticks (the marks on the Axis) and ticklabels (strings labeling the ticks).
#
# d. Basically, everything visible on the Figure is an Artist (even Figure, Axes, and Axis objects). This includes Text objects, Line2D objects, collections objects, Patch objects, etc. When the Figure is rendered, all of the Artists are drawn to the canvas. Most Artists are tied to an Axes; such an Artist cannot be shared by multiple Axes, or moved from one to another.

# %% [markdown]
# ---
# **2)**	[PM] Let's read in a dataset about Frosted Flakes breakfast (or, what any other country would refer to as dessert) cereal. Read about the data [here](https://vincentarelbundock.github.io/Rdatasets/doc/DAAG/frostedflakes.html)
#
# The [CSV file](https://vincentarelbundock.github.io/Rdatasets/csv/DAAG/frostedflakes.csv)
#
# You'll notice that the first variable is nothing more than an index. Normally, I keep all supplied index variables, but this time we'll drop it.
#
# Add this code into the cell to read in the file directly from the URL and drop the first column:
#
# ```
# df_fflakes = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/DAAG/frostedflakes.csv")
# # Drop first column
# df_fflakes.drop(columns=df_fflakes.columns[0],inplace=True)
# df_fflakes
# ```
# Then, write a sentence or two describing the data in a markdown cell.

# %% [markdown]
# **ANSWER:**
#
# The data measures 100 samples of 25g cereal. Each sample has two values, Lab, which corresponds to the measurement of sugar concentration using high performance liquid chromatography, and IA400, which corresponds to the measurement of sugar concentration using the infra-analyzer 400.

# %%
# ANSWER:

df_fflakes = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/DAAG/frostedflakes.csv")
# Drop first column
df_fflakes.drop(columns=df_fflakes.columns[0],inplace=True)
df_fflakes
# Out:
#      Lab  IA400
# 0   36.3   35.1
# 1   33.2   35.9
# 2   39.0   40.1
# 3   37.3   35.5
# 4   40.7   37.9
# ..   ...    ...
# 95  38.9   42.0
# 96  39.3   42.6
# 97  37.1   40.8
# 98  35.6   40.2
# 99  36.8   40.6
#
# [100 rows x 2 columns]

# %% [markdown]
# ---
# **3)**	[P] Use the `describe()` method to show essential summary statistics about these data

# %%
# ANSWER:

df_fflakes.describe()
# Out:
#               Lab       IA400
# count  100.000000  100.000000
# mean    37.596000   38.218000
# std      2.467359    2.790293
# min     31.600000   30.800000
# 25%     36.000000   36.100000
# 50%     37.750000   38.500000
# 75%     39.100000   40.200000
# max     43.500000   45.700000

# %% [markdown]
# ---
# **4)**	[M] What is a **scatterplot**? What does it show? What type of data is it used for? Is it good for one variable, or more?

# %% [markdown]
# **ANSWER:**
#
# From ChatGPT:
#
# A scatter plot is a type of plot that displays individual data points as dots (or "markers") on a two-dimensional Cartesian plane. The position of each marker is determined by the value of two variables, one plotted on the x-axis and the other on the y-axis. Scatter plots are often used to visualize the relationship between two variables, such as to identify any correlations or patterns. Scatter plots can also display additional information about each data point, such as size and color, which can provide additional insights into the data.
#
# They are particularly useful when the data consists of paired observations, such as the height and weight of a group of people, or the time spent studying and scores on a test. Scatter plots can be used with any type of continuous or numerical data, but they are not well-suited for categorical data.

# %% [markdown]
# ---
# For many of these plotting questions, the [matplotlib Pyplot tutorial](https://matplotlib.org/stable/tutorials/introductory/pyplot.html) has good, basic examples to help you.

# %% [markdown]
# ---
# **5)**	[P] Generate a scatterplot of the data using matplotlib's `scatter` method. The tutorial and examples for matplotlib have plenty of examples that are very close to what you need. Your plot must:
# a.	Have a title
# b.	Label both axes appropriately
# c.	Limit the range of both axis to be etween 30 and 50
# d.	Change the default point size
# e.	Change the default color of the point
# f.	Display a grid

# %%
# ANSWER:

plt.scatter(df_fflakes['Lab'], df_fflakes['IA400'], s=100, c='red')
plt.title("Frosted Flakes Sugar Concentration using Different Methods of Measurement")
plt.xlabel("Lab")
plt.ylabel("IA400")
plt.xlim(30, 50)
plt.ylim(30, 50)
plt.grid = True
plt.show()

# %% [markdown]
# ---
# **6)**	[PM] Check out [this dataset related to bad health](https://vincentarelbundock.github.io/Rdatasets/doc/COUNT/badhealth.html)
#
# Write in your markdown cell a few sentences about the data and the variables. Then, read in [the data](https://vincentarelbundock.github.io/Rdatasets/csv/COUNT/badhealth.csv).
#
# When you read in your data, this time, use the supplied index variable as the actual index for your dataframe. (HINT: Use the parameter `index_col=0` in `pd.read_csv()`)
#
# After you read in your data, it's good to show the first few observations instead of the entire dataframe. Use the `.head()` method on the dataframe.

# %% [markdown]
# **ANSWER:**

# %%
# ANSWER

df_badhealth = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/COUNT/badhealth.csv",
                           index_col=0)
df_badhealth.head()
# Out:
#    numvisit  badh  age
# 1        30     0   58
# 2        20     0   54
# 3        16     0   44
# 4        20     0   57
# 5        15     0   33

# %% [markdown]
# ---
# **7)**	[PM] Start to explore these three variables. Use `describe()` but also be sure to pay attention to`info()` and ask yourself if each type is the most correct type. All three were likely read in as numeric. That's OK for `numvisit` and `age`, but what about `badh`? What is the type of that variable?

# %%
# ANSWER:

df_badhealth.describe()
# Out:
#           numvisit         badh          age
# count  1127.000000  1127.000000  1127.000000
# mean      2.353150     0.099379    37.228926
# std       3.461466     0.299303    10.828919
# min       0.000000     0.000000    20.000000
# 25%       0.000000     0.000000    28.000000
# 50%       1.000000     0.000000    35.000000
# 75%       3.000000     0.000000    46.000000
# max      40.000000     1.000000    60.000000

# %%
df_badhealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 1 to 1127
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   numvisit  1127 non-null   int64
#  1   badh      1127 non-null   int64
#  2   age       1127 non-null   int64
# dtypes: int64(3)
# memory usage: 35.2 KB

# %% [markdown]
# The type of badh is also int64.

# %% [markdown]
# ---
# **8)**	[P] What is the distribution of the `badh` variable? Or, in other words, what is the count of different values in this variable?

# %%
# ANSWER:

df_badhealth.badh.value_counts()
# Out:
# 0    1015
# 1     112
# Name: badh, dtype: int64

# %% [markdown]
# ---
# **9)**	[P] Change the `badh` variable from a numeric variable to true categorical variable

# %%
# ANSWER:

df_badhealth.badh =  df_badhealth.badh.astype('category')\
    .replace({0: 'good', 1: 'bad'})

# %% [markdown]
# ---
# **10)**	[P] Using matplotlib, generate a **single figure** that contains **two axes**. Each axes should be adjacent to each other. Each axes should show a scatterplot relating the age to the number of visits, but separate each plot dependent on whether the patient is in good or bad health. You should have:
# a.	at least one shared axis
# b.	appropriate axis labels
# c.	make the range of the axis on both plots the same
# d.	display a legend on each to be sure both are labeled correctly
# e.	One title at the top
#
# NOTE: This is a good example of why you need to carefully select the plot that is most apporpriate for the data. You'll find this plot to be uninformative. It's a poor choice, partly due to the discrete nature of the `age` variable, and partly because a scatterplot can not reveal distinguishing characteristics between distributions between bad and good health. Generate the plot anyway. You'll see a *much* better way to visualize these two variables by health when you get to boxplots later.

# %%
# ANSWER: partly used ChatGPT

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

good_health = df_badhealth[df_badhealth.badh == 'good']
bad_health = df_badhealth[df_badhealth.badh == 'bad']

ax1.scatter(good_health.age, good_health.numvisit,
            label= 'Person with Good Health')
ax1.set_title("Good Health")
ax1.set_xlabel("Age")
ax1.set_ylabel("Number of Visits")
ax1.set_ylim(0, 50)
ax1.legend(loc='best')

ax2.scatter(bad_health.age, bad_health.numvisit,
            label='Person with Bad Health')
ax2.set_title("Bad Health")
ax2.set_xlabel("Age")
ax2.set_ylabel("Number of Visits")
ax2.set_ylim(0, 50)
ax2.legend(loc='best')

plt.suptitle("Number of Visits to Doctors Related to Age")

plt.show()

# %% [markdown]
# ---
# **11)**	[M] What is a **histogram**? In your answer, in addition to defining it, please clearly indicate what type of data its good for, and whether it's good for one variable or to show relationships between multiple variables.

# %% [markdown]
# **ANSWER:**
#
# ChatGPT:
#
# A histogram is a graphical representation of the distribution of a dataset. It shows the frequency of data points within a certain range of values, called bins. The bins are usually represented as bars in the histogram, and the height of each bar represents the number of data points that fall within the corresponding range of values.
#
# Histograms are good for visualizing the distribution of continuous data. They can provide information about the shape of the distribution, such as whether it is symmetrical or skewed, as well as the presence of outliers. By examining a histogram, it is possible to identify the central tendency, variability, and skewness of a dataset.
#
# Histogram is generally used for showing the data for one variable, but it can also show the relation of multiple variables. Plotting multiple histograms in a same figure is possible, using different colors to distinguish the different variables. However, it is not the most effective way in most cases.

# %% [markdown]
# ---
# **Pandas interface to matplotlib** - Pandas has a very simple interface to generating quick plots. It's actually quite impressive. It uses matplotlib, thus allowing you to make modifications to the generated plots, though quite often you'll see the default plots generated form Pandas are fine for quick visualizations.
#
# See [Pandas API to plotting](https://pandas.pydata.org/docs/user_guide/visualization.html) for more information

# %% [markdown]
# ---
# **12a)**	[P] Let's explore the Pandas interface to plotting. Generate a histogram for the cereal data using the `hist()` method of `DataFrame` objects. Use 20 bins, and set the range of both variables to be 30-50.

# %%
# ANSWER:

df_fflakes.hist(range=(30, 50), bins=20)
plt.suptitle("Frosted Flakes Sugar Concentration using Different Methods of Measurement")
plt.show()

# %% [markdown]
# ---
# **12b)** [P] Usually the `plot()` interface in Pandas dataframes is a bit more powerful. Generate a histogram for the same data, but this time, use the `plot()` method. Specify with the parameter `kind="hist"` to get a histogram. See what that looks like, and then generate the same with `alpha=0.5`. Set `bins=20` to show similar output as the previous questions.

# %%
# ANSWER

df_fflakes.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df_fflakes.plot(kind="hist", alpha=0.5, bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ---
# **13)**	[M] What is a quantile?

# %% [markdown]
# **ANSWER:**
#
# It is a value that separates data into equally divided intervals to measure the rank og the data.

# %% [markdown]
# ---
# **14)** [M] In terms of quantiles, what is a quartile? What about a percentile? What is an Inter-quartile range (IQR)?

# %% [markdown]
# **ANSWER:**
#
# Partially ChatGPT:
#
# A quartile separates the data into 4 intervals, each interval is 25% of the whole set. A percentile is the same as a quantile. The IQR is the range of the middle two intervals of a quartile. It is defined as the difference between the 75th percentile (the third quartile) and the 25th percentile (the first quartile) of the data. It is used to define outliers.

# %% [markdown]
# ---
# **15)**	[M, P] Read about the `quantile()` method for data frames, and use it to numerically report the 25th, median, and 75th percentiles. Then, compute the IQR (Inter-quartile range for `age` and `numvisit` variables. Report the IQR for healthy and sick individuals separately. Discuss your findings.

# %%
# ANSWER:

print("Good Health 25%: ")
print(good_health.quantile(0.25, numeric_only=True))
print("Good Health 50%: ")
print(good_health.quantile(0.5, numeric_only=True))
print("Good Health 75%: ")
print(good_health.quantile(0.75, numeric_only=True))

print("\nBad Health 25%: ")
print(bad_health.quantile(0.25, numeric_only=True))
print("Bad Health 50%: ")
print(bad_health.quantile(0.5, numeric_only=True))
print("Bad Health 75%: ")
print(bad_health.quantile(0.75, numeric_only=True))

print("\nGood Health Inter-Quartile Range: ")
print(good_health.quantile(0.75, numeric_only=True) -
      good_health.quantile(0.25, numeric_only=True))

print("\nBad Health Inter-Quartile Range: ")
print(bad_health.quantile(0.75, numeric_only=True) -
      bad_health.quantile(0.25, numeric_only=True))
# Out:
# Good Health 25%:
# numvisit     0.0
# age         28.0
# Name: 0.25, dtype: float64
# Good Health 50%:
# numvisit     1.0
# age         34.0
# Name: 0.5, dtype: float64
# Good Health 75%:
# numvisit     3.0
# age         45.0
# Name: 0.75, dtype: float64
#
# Bad Health 25%:
# numvisit     2.0
# age         35.0
# Name: 0.25, dtype: float64
# Bad Health 50%:
# numvisit     4.0
# age         45.0
# Name: 0.5, dtype: float64
# Bad Health 75%:
# numvisit     9.25
# age         52.25
# Name: 0.75, dtype: float64
#
# Good Health Inter-Quartile Range:
# numvisit     3.0
# age         17.0
# dtype: float64
#
# Bad Health Inter-Quartile Range:
# numvisit     7.25
# age         17.25
# dtype: float64

# %% [markdown]
# I find that the numvisit variable is more spread out for people who have bad health than people who have good health. The age variable's spread is pretty similar between the two.

# %% [markdown]
# ---
# **16)**	[M] There are many ways to define what we mean by an outlier. A very common technique is known as the IQR rule for outliers. What is a definition of an outlier in terms of IQR? (Big hint: Your answer should incorporate some use of 1.5 * IQR, and note that notebook markdown supports embedded $LaTeX$, such as using $Q1 - 1.5 * IQR$)

# %% [markdown]
# **ANSWER:**
#
# From ChatGPT:
#
# The lower bound is defined as $Q1 - 1.5 * IQR$, while the upper bound is defined as $Q3 + 1.5 * IQR$. Any value that is below the lower bound or above the upper bound is considered an outlier.

# %% [markdown]
# ---
# **17)** [P] Write a function called `IQR_outlier_limits` that takes a dataframe as input, and computes the minimum and maximum outlier thresholds for each variable (numeric only assumed), stored in a data frame that is returned as a result.

# %%
# ANSWER:

def IQR_outlier_limits(df):
    """ Compute the outlier limits based on the 1.5 * IQR rule
        Input: A DataFrame
        Output: a DataFrame of the minimum and maximum outlier thresholds for all 
                numeric variables
    """
    Q1 = df.quantile(0.25, numeric_only=True)
    Q3 = df.quantile(0.75, numeric_only=True)
    IQR = Q3 - Q1

    lower_outlier_threshold = Q1 - 1.5 * IQR
    upper_outlier_threshold = Q3 + 1.5 * IQR

    return pd.DataFrame({"min_out": lower_outlier_threshold,
                      "max_out": upper_outlier_threshold}).T.iloc[:, ::-1]

# %% [markdown]
# ---
# **18)**	Show the result of your `IQR_outlier_limits` function on the numeric variables (age and numvisit) of `df_badhealth`.
#
# HINT:  Your answer should look something like:
# ```
#           age  numvisit
# min_out   1.0      -4.5
# max_out  73.0       7.5
# ```

# %%
# ANSWER

health_outlier_thresholds = IQR_outlier_limits(df_badhealth)
health_outlier_thresholds
# Out:
#           age  numvisit
# min_out   1.0      -4.5
# max_out  73.0       7.5

# %% [markdown]
# ---
# **19)**	[MP] Use your function you defined above to print the observations where the number of visits seems to be an outlier according to the IQR rule. Then, show the value counts for the badh variable. Draw your conclusions about whether good or bad health patients seems to have more outliers. (HINT: If you say they are both equally likely to have outliers, you'd be wrong!)

# %%
# ANSWER
min_outlier = df_badhealth['numvisit'] < health_outlier_thresholds.at['min_out', 'numvisit']
max_outlier = df_badhealth['numvisit'] > health_outlier_thresholds.at['max_out', 'numvisit']
pd.concat([df_badhealth[min_outlier], df_badhealth[max_outlier]]).badh.value_counts()
# Out:
# bad     36
# good    35
# Name: badh, dtype: int64

# %% [markdown]
# **ANSWER:**
#
# Although the numbers of people with good and bad health are approximately the same, we have see that there are 1015 people with good health and 112 people with bad health in this data frame. Thus, we can safely say that the number of people with bad health is more likelly to have outliers.

# %% [markdown]
# ---
# **20)**	[M] What is a box plot? (A.k.a boxplot, box-and-whisker plot). In your answer, please clearly indicate what it is, what type of data its good for, and whether it's good for one variable or to show relationships between multiple variables.

# %% [markdown]
# **ANSWER:**
#
# ChatGPT:
#
# The plot represents the distribution of numerical data by displaying the median, quartiles, and range of the data in the form of a box. The box shows the interquartile range (IQR), which is the range between the first (25th) and third (75th) quartiles, and the whiskers extend from either side of the box to show the range of the data. Outliers, which are data points that lie far away from the other data points, can also be displayed as individual dots.
# Box Plots are good at visualizing numerical data that have multiple observations for each individual data point, such as data from a sample or a population.
# It is mostly used for visualizing the distribution of one variable.

# %% [markdown]
# ---
# **21)**	[P] Again, use the pandas DataFrame plotting interface to generate a box plot on the cereal data. Then, do the same again on the bad health data, but group by the badh variable.

# %%
# ANSWER:
df_fflakes.plot(kind='box')
plt.title("Frosted Flakes Sugar Concentration using Different Methods of Measurement")
plt.xlabel("Methods")
plt.ylabel("Sugar Concentration")
plt.show()

# %%
df_badhealth.groupby('badh').plot(kind='box')
plt.show()

# %% [markdown]
# ---
# **22)**	[M] From your understanding of a box plot, summarize the distribution of these data. You should be using the correct terminology, meaning, interpreting the box plot results in terms of quartiles, outliers, etc.

# %% [markdown]
# **ANSWER:**
#
# The people who consider themselves as healthy have more outlier in numvisit than the people who consider themselves as unhealthy. The medium of numvisit for healthy people is less than the medium of numvisit for unhealthy people.The IQR of the healthy people is smaller than the unhealthy people, and thus has a smaller spread. The data for both are right skewed. The age of the people are all from 20 to 60, and no outlier because the dataset only contains people in this age range. The unhealthy people has a higher medium age than the healthy people, and is right skewed, compared to the age of the healthy people, which is left skewed.

# %% [markdown]
# ---
# **23)**	[M] What is a **density** plot? In your answer, please clearly indicate what it is, type of data you use it for, and whether it's good for one variable or to show relationships between multiple variables.

# %% [markdown]
# **ANSWER:**
#
# ChatGPT:
#
# A density plot is a representation of the distribution of a set of continuous variables. It is a smoothed, continuous version of a histogram and is used to visualize the probability density function of a given set of data. The plot shows the estimated probability density at different values, with the area under the curve representing the total probability.
# It is good for one variable and showing relationships between multiple variables.

# %% [markdown]
# ---
# **24)**	[P] Use the pandas interface to generate a density plot for both variables in the cereal data. The plots should appear overlaid in a single figure.

# %%
# ANSWER

df_fflakes.plot(kind='density')
plt.title("Sugar Concentration Measurement Using Different Methods")
plt.xlabel("Sugar Concentration")
# Out:
# Text(0.5, 0, 'Sugar Concentration')

# %% [markdown]
# ---
# **25)**	[M] Interpret the density plot results

# %% [markdown]
# **ANSWER:**
#
# By looking at the density plot, we can see that both of the datasets acquired by Lab and IA400 appear to be normally distributed. The data of IA400 appears to detect larger density from sugar cencentration 27 to 32, detect less density from 32 to 39, and larger density from 39 to 47. This means the sugar concentration of the cereal is mostly around 38. The two methods also produce similar but not completely the same results.

# %% [markdown]
# ---
# **26)**	[M] What is a quantile-quantile plot? (Wikipedia provides a good answer for this.)

# %% [markdown]
# **ANSWER:**
#
# From Wikipedia:
#
# In statistics, a Q–Q plot is a probability plot, a graphical method for comparing two probability distributions by plotting their quantiles against each other. A point on the plot corresponds to one of the quantiles of the second distribution plotted against the same quantile of the first distribution.

# %% [markdown]
# ---
# **27)**	[P] Let's use `scipy.stats`, typically loaded with the alias `stats`. Look up the API and read about the [probplot](http://www.statsmodels.org/dev/generated/statsmodels.graphics.gofplots.qqplot.html#statsmodels.graphics.gofplots.qqplot) This can generate a Q-Q plot for you quite easily.
#
# So, suppose you didn't know whether your data was uniform or normally distributed. Generate a Q-Q plot for the Lab variable in df_fflakes. Generate a plot assuming a `uniform` distribution, and another plot for the `norm` distribution.

# %%
# ANSWER

import scipy.stats as stats
fig, (ax1, ax2) = plt.subplots(1, 2)
stats.probplot(df_fflakes['Lab'], dist='uniform', plot=ax1)
ax1.set_title("Uniform Distribution")
stats.probplot(df_fflakes['Lab'], dist='norm', plot=ax2)
ax2.set_title("Normal Distribution")
plt.show()

# %% [markdown]
# ---
# **28)**	[M] Compare and contrast your resulting plots above. Does the output suggest that the Lab variable is more normal than uniform?

# %% [markdown]
# **ANSWER:**
#
# By looking at the plots, it does suggest that hte lab variable is more normal than uniform, because the points in the normal distribution sticks more closely to the reference line than in the uniform distribution.

# %% [markdown]
# ---
# # Part II - Seaborn
#
# For the questions in this section, you are to use the Seaborn interface.
# ---

# %% [markdown]
# **29)**	[P] Show a scatterplot of the bad health data, showing age as your x and numvisit as your y, faceted dependent on badh. (HINT: FacetGrid will make this quite easy! In fact you should be able to generate this in two lines of code!)

# %%
# ANSWER:

# ChatGPT:
import seaborn as sns
bad_health_scatter = sns.FacetGrid(df_badhealth, col='badh')
bad_health_scatter.map(sns.scatterplot, "age", "numvisit")

# %% [markdown]
# ---
# **30)** [P] Show the distribution of only the age variable for the bad health data. Show both healthy and poor health as different colors, and you should overlay a density curve with a histogram in your result. (HINT: Use `histplot` with the `hue` parameter.)

# %%
# ANSWER

sns.histplot(x='age', hue='badh', data=df_badhealth, kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ---
# **31)**	[M] The above output is great for comparing the distribution of a single variable, while using color to separate your data dependent on a categorical variable. Sometimes with "imbalanced" data (i.e. the data is not equally distributed between your different levels, as is the case with badh), it's a bit hard to see differences between the distribution of variables that are dependent on another variable.This is the case above (if you did it right.)
#
# So, rework the previous exercise to show a *conditional probability distribution* for each `badh` level.
#
# HINT: You can make consecutive calls to seaborn and as long as the plots are compatible, they will be superimposed on the same plot. Also, the parameter `stat="probability"` may be helpful here!

# %%
# ANSWER:

g = sns.FacetGrid(df_badhealth, col="badh", col_wrap=2)
g.map(sns.histplot,"age" , kde=True, stat="probability")
plt.suptitle("Age Probability Distribution")
plt.show()

# %% [markdown]
# ---
# **32)** What is a `jointplot` in Seaborn?

# %% [markdown]
# **ANSWER:**
#
# From ChatGPT:
#
# jointplot is a function in the seaborn library in Python that is used to visualize the relationship between two variables. It combines a scatter plot with histograms (or kernel density estimates) of the individual variables to give a representation of the bivariate distribution of the data.

# %% [markdown]
# ---
# **33)**	[P] Use `sns.jointplot` to show the bivariate distribution of `Lab` and `IA400` on the cereal data

# %%
#ANSWER

sns.jointplot(x="Lab", y="IA400", data=df_fflakes)
plt.suptitle("Bivariate Distribution of Lab and IA400 Methods on Cereal Data")
plt.show()

# %% [markdown]
# ---
# **34)**	[P] Show a hexbin plot using sns.jointplot for df_flakes

# %%
# ANSWER:

sns.jointplot(x="Lab", y="IA400", data=df_fflakes, kind="hex")
plt.suptitle("Bivariate Distribution of Lab and IA400 Methods on Cereal Data")
plt.show()

# %% [markdown]
# ---
# **35)**	Let's checkout a popular, but simple public dataset on tooth growth in Guinea Pigs. Here is a [simple description of the data](https://vincentarelbundock.github.io/Rdatasets/doc/datasets/ToothGrowth.html)
#
# Open up the [csv file](https://vincentarelbundock.github.io/Rdatasets/csv/datasets/ToothGrowth.csv) and examine the format. Show the first few records using the `head()` method. You should see that the first column is your index. It has a header row. There are two numeric variables (len, dose), and one nominal ("supp"). (HINT: You'll need to specify the `index_col` parameter when one of the columns supplied is a row number or an index.)

# %%
# Read in the data in CSV

df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/datasets/ToothGrowth.csv", index_col=0)
df.head()
# Out:
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %% [markdown]
# ---
# **36)**	Look at the info() and describe() output. You will see that len and dose are in the correct format. However, you need to change the supp variable into a true Categorical type. Look up pd.Categorical and change df.supp into an unordered categorical (i.e. nominal) variable. Confirm that you did this by showing the output of df.info()

# %%
#ANSWER
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000

# %%
df.supp = df.supp.astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     category
#  2   dose    60 non-null     float64
# dtypes: category(1), float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ---
# **37)**	Generate a scatterplot (remember, all plots in this section should be with Seaborn) showing the dose as x, and the length as y. Set the hue as the supp variable. Be sure to title and label your graphs.

# %%
#ANSWER

sns.scatterplot(x="dose", y='len', data=df, hue="supp")
plt.title("The Effect of Different Supplements on Tooth Growth in Guinea Pigs")
plt.xlabel("Dose of Supplement in milligrams/day")
plt.ylabel("Tooth Length")
plt.show()

# %% [markdown]
# ---
# **38)**	[PM] Once again, you'll see a rather uninformative graph for similar reasons we saw earlier. However, even with a crap graph like this, you should see that there is an obvious correlation between dose and length. You should also see that the dose is a **controlled** dose, with only three possible values given. This is our critical experimental, independent variable in this study! In theory, it's really a type of nominal or ordinal variable, but we will leave it as numeric. Let's do better than a scatterplot.
#
# Start by looking up `catplot` in Seaborn.  This is a high level interface to a variety of categorical plots. Use it to create a stripplot.

# %%
# ANSWER

sns.catplot(x="dose", y="len", data=df, hue="supp", kind="strip")
plt.title("The Effect of Different Supplements on Tooth Growth in Guinea Pigs")
plt.xlabel("Dose of Supplement in milligrams/day")
plt.ylabel("Tooth Length")
plt.show()

# %% [markdown]
# ---
# **39)** That's a bit better, but we can do better. Create a histogram for tooth length with the hue set to the supplement. Overlap the density graph. Then, in a followup markdown cell, comment on the effect that the supplement alone might have on tooth length. Which do you think results in longer tooth length?

# %%
# ANSWER

sns.histplot(x="len", hue="supp", data=df, bins=20, kde=True)
plt.title("Tooth Length Distribution")
plt.xlabel("Tooth Length")
plt.ylabel("Number of Teeth")
plt.show()

# %% [markdown]
# Although I am not certain if this dataset is enough to determine which supplement results in longer teeth, but by also applying a density curve to the graph, I think OJ results in longer teeth growth. When the length gets larger on the graph, we see that OJ was used more than VC in most cases. The longest two by VC might be outliers.

# %% [markdown]
# ---
# **40)**	[PM] Create a boxplot showing the distribution of length by dose, and also set the hue again to be supp. Comment on your findings.

# %%
# ANSWER

sns.boxplot(x="dose", y="len", data=df, hue="supp")
plt.title("The Effect of Different Supplements on Tooth Growth in Guinea Pigs")
plt.xlabel("Dose of Supplement in milligrams/day")
plt.ylabel("Tooth Length")
plt.show()

# %% [markdown]
# I find that for lower doses (0.5, 1.0), OJ uses generally result in longer teeth. I got it from observing the median and the IQR. The medians of OJ are higher than the medians of VC, and the IQRs of OJ are mostly higher than the IQRs of VC. For the 2.0 dose, however, OJ and VC have the same median, while VC has a greater spread, with a wider IQR.

# %% [markdown]
# ---
# **41)**	[PM] Ha! Now we're getting somewhere! This is quite an informative plot. A violinplot is a similar popular visualization that can convey a lot of information about the distribution of your variables onto one plot. Some prefer these over boxplots. Read about violinplots in the Seaborn API, then use it to redo the previous boxplot, but set `split=True`. Then, redo it with `split=False`. Comment on your findings.

# %%
# ANSWER

sns.violinplot(x="dose", y="len", data=df, hue="supp", split=True)
plt.title("The Effect of Different Supplements on Tooth Growth in Guinea Pigs")
plt.xlabel("Dose of Supplement in milligrams/day")
plt.ylabel("Tooth Length")
plt.show()

# %%
sns.violinplot(x="dose", y="len", data=df, hue="supp", split=False)
plt.title("The Effect of Different Supplements on Tooth Growth in Guinea Pigs")
plt.xlabel("Dose of Supplement in milligrams/day")
plt.ylabel("Tooth Length")
plt.show()

# %% [markdown]
# I find that violin plots have the distribution drawn out, so we can look at the shapes of the graphs better. The split parameter specifies how the graphs are located adjacent to each other. split=True makes the graphs placed against each other and provides a closer comparison. split=False makes the graphs placed side by side for a clearer view of each graph, but can still compare them.

# %% [markdown]
# ---
# # Part III - Discretization
# ---
#
# As we learn about doing EDA and prepping our data, we're learning that visualizing our data to get a good understanding of our variables is important. We're also learning that we can make a variety of transformations with our variables in ways that let us do more meaningful visualizations (and also, as we'll soon understand, modeling).
#
# One common transformation is called **discretization**. It's the process of converting a numeric variable into a categorical variable, more specifically, usually an ordinal.
#
# A common way of referring to categorical variables are **factors**. Factors are explanatory categorical variables in a controlled experiment. They typically only take on a small number of values, called **levels**.

# %% [markdown]
# ---
# **42)**	[P] Create an additional variable in df_badhealth called `age_fac1` that represents a factor with 3 levels, "young", "mid", and "older". You should discretize according to equal width bins over the distribution of the age variable.

# %%
# ANSWER

# ChatGPT:

bin_edges = pd.cut(df_badhealth['age'], bins=3, retbins=True)[1]
df_badhealth['age_fac1'] = pd.cut(df_badhealth['age'],
                                  bins=bin_edges,
                                  labels=['young', 'mid', 'older'])

# %% [markdown]
# ---
# **43)**	[P] Create an additional variable in df_badhealth called age_fac2 that represents a factor with 3 levels, "young", "mid", and "older". However, this time you should discretize using equal depth bins over the distribution of age. (i.e. the division is chosen to try and get close to an equal number of observations in each bin as possible.) Show the value counts for df_badhealth.age_fac2.

# %%
# ANSWER

bin_edges = pd.qcut(df_badhealth['age'], q=3, retbins=True)[1]
df_badhealth['age_fac2'] = pd.cut(df_badhealth['age'],
                                  bins=bin_edges,
                                  labels=['young', 'mid', 'older'])
df_badhealth.age_fac2.value_counts()
# Out:
# young    383
# mid      373
# older    356
# Name: age_fac2, dtype: int64

# %% [markdown]
# ---
# **44)**	[P] Create a side by side scatter plot showing the distribution of `df_badhealth`, showing `numvisit` dependent on age. However, use `age_fac1` as your hue for the left plot, and `age_fac2` as your hue for the right plot. This will demonstarate how cut points slightly differ depending on the method you use to discretize the data.

# %%
# ANSWER

fig, ax = plt.subplots(1, 2)
sns.scatterplot(x="age", y="numvisit", data=df_badhealth, hue="age_fac1", ax=ax[0])
sns.scatterplot(x="age", y="numvisit", data=df_badhealth, hue="age_fac2", ax=ax[1])
plt.suptitle("Relationship Between People's Age Range and Number of Doctor Visits")
plt.show()

# %% [markdown]
# ---
# **45)**	[P] Show a box plot of the number of visits dependent on either `age_fac1` or `age_fac2`. You should see a very strong difference in the distribution of the number of visits depending on their health in all three age brackets. If you do it right, you'll see perhaps the most informative plot showing how the number of visits is strongly affected by whether you are healthy or sick, regardless of your age.

# %%
# ANSWER

sns.boxplot(df_badhealth, x="age_fac1", y="numvisit", hue="badh")
plt.title("The Number of Visits Depending on People's Health")
plt.xlabel("Age")
plt.ylabel("Number of Visits")
plt.show()

# %% [markdown]
# ---
# # STOP HERE! You're done!
#
# 1.	Be sure you have every cell run, and output generated.
# 2.	Commit and push `lab05.ipynb`. Verify that your file is pushed properly on Gitlab.
# 3.	Generate a paginated PDF file of your notebook and upload to Gradescope
# 4.	Be sure to select the pages that have the specified questions, and submit when done
